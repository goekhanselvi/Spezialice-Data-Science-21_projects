# %% [markdown]
# # Billionaires Analysis with Python

# %% [markdown]
# <img src='Billionaires.jpg'>

# %% [raw]
# 2021 Milyarderler Analizi Projesi
# Bu proje, 2021 yılında dünya genelindeki milyarderlerin ekonomik durumu, varlıkları ve demografik özelliklerini analiz etmeyi amaçlamaktadır. Proje, veri analizi ve görselleştirme tekniklerini kullanarak milyarderlerin profilini anlamaya yönelik önemli bilgiler sunacaktır.
#
# Bu proje, veri analizi becerilerinizi geliştirmekle kalmayıp, milyarderlerin ekonomik durumu hakkında derinlemesine bir anlayış kazanmanızı sağlayacaktır. Veri biliminde karşılaşılan temel adımları deneyimleyerek, gerçek dünya verileri üzerinde çalışma fırsatı bulacaksınız.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Billionaire.csv')

# %%
data.head()
# Out:
#                        Name NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
data.isnull().sum()
# Out:
# Name         0
# NetWorth     0
# Country      0
# Source       0
# Rank         0
# Age         79
# Industry     0
# dtype: int64

# %%
# Age sütununda bos veriler var. Bunu simdilik siliyoruz.

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Name        0
# NetWorth    0
# Country     0
# Source      0
# Rank        0
# Age         0
# Industry    0
# dtype: int64

# %%
# NetWorth yani Gelir sütunundaki $ ve B isaretlerini kaldiriyoruz
data["NetWorth"] = data["NetWorth"].str.strip("$")
data["NetWorth"] = data["NetWorth"].str.strip("B")
data["NetWorth"] = data["NetWorth"].astype(float)

# %%
data.head(10)
# Out:
#                        Name  NetWorth        Country              Source  \
# 0                Jeff Bezos     177.0  United States              Amazon
# 1                 Elon Musk     151.0  United States       Tesla, SpaceX
# 2  Bernard Arnault & family     150.0         France                LVMH
# 3                Bill Gates     124.0  United States           Microsoft
# 4           Mark Zuckerberg      97.0  United States            Facebook
# 5            Warren Buffett      96.0  United States  Berkshire Hathaway
# 6             Larry Ellison      93.0  United States            software
# 7                Larry Page      91.5  United States              Google
# 8               Sergey Brin      89.0  United States              Google
# 9             Mukesh Ambani      84.5          India         diversified
#
#    Rank   Age               Industry
# 0     1  57.0             Technology
# 1     2  49.0             Automotive
# 2     3  72.0       Fashion & Retail
# ...

# %%
df = data.sort_values(by = ["NetWorth"], ascending=False).head(10)
plt.figure(figsize=(20, 10))
sns.histplot(x="Name", hue="NetWorth", data=df)
plt.show()

# %%
a = data["Source"].value_counts().head()
index = a.index
sources = a.values
custom_colors = ["skyblue", "yellowgreen", 'tomato', "blue", "red"]
plt.figure(figsize=(5, 5))
plt.pie(sources, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Domains to Become a Billionaire", fontsize=20)
plt.show()

# %%
a = data["Industry"].value_counts().head()
index = a.index
industries = a.values
custom_colors = ["skyblue", "yellowgreen", 'tomato', "blue", "red"]
plt.figure(figsize=(5, 5))
plt.pie(industries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Industries with Most Number of Billionaires", fontsize=20)
plt.show()

# %%
a = data["Country"].value_counts().head()
index = a.index
Countries = a.values
custom_colors = ["skyblue", "yellowgreen", 'tomato', "blue", "red"]
plt.figure(figsize=(5, 5))
plt.pie(Countries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Countries with Most Number of Billionaires", fontsize=20)
plt.show()

# %%
df['Country'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [raw]
# Yukarıdaki görselleştirme, ABD ve Çin'in çoğu insanın milyarder olduğu ülkeler olduğunu gösteriyor. Yani bu, dünyanın geri kalanıyla karşılaştırıldığında ABD ve Çin'de iş ortamının ve başlangıç başarı oranının gerçekten iyi olduğu anlamına geliyor.

# %% [raw]
# Özet
# Ülkelerin iş ortamını analiz etmek için dünya çapındaki milyarderler arasında kalıpları bu şekilde bulabilirsiniz. Bir işletmenin veya girişimin başarısı büyük ölçüde bir ülkenin iş ortamına bağlıdır. Küresel milyarderlerin analizi sonunda Çin ve ABD'nin en fazla milyardere sahip ülkeler olduğunu buldum ve bu da ABD ve Çin'de bir startup'ın iş ortamının ve başarı oranının geri kalanına göre çok daha iyi olduğu sonucuna vardım.
