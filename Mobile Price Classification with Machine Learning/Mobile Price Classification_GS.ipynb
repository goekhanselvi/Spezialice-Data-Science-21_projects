# %% [markdown]
# # Mobile Price Classification with Machine Learning

# %% [markdown]
# <img src='mobile.jpg'>

# %% [raw]
# Bir ürünün fiyatı, o ürünü pazarlamanın en önemli özelliğidir. Fiyatın çok önemli olduğu ürünlerden biri akıllı telefondur çünkü birçok özellikle birlikte gelir, böylece bir şirket bu cep telefonunu nasıl fiyatlandıracağı konusunda çok düşünür, bu da özellikleri haklı gösterebilir ve aynı zamanda cep telefonunun pazarlama ve üretim maliyetlerini de karşılayabilir. Bu yazıda, Python kullanarak Makine Öğrenimi ile mobil fiyat sınıflandırması görevi hakkında size yol göstereceğim.
#
# Makine Öğrenimi ile Mobil Fiyat Sınıflandırması
# İnsanlar yeni bir cihazda yeni özellikler bulduklarında cep telefonlarını güncellemeye devam ettikleri için cep telefonları en çok satan elektronik cihazlardır. Günlük binlerce cep telefonu satılıyor, böyle bir durumda kendi cep telefonu işini kurmayı planlayan birinin cep telefonunun fiyatının ne olması gerektiğine karar vermesi çok zor bir iş.
#
# Aşağıdaki bölümde, size Python kullanarak cep telefonlarının fiyat aralığını sınıflandırmak için bir model eğiteceğim bir mobil fiyat sınıflandırma modeli üzerinde bir makine öğrenimi projesini tanıtacağım. Bu görev aşağıda belirtilen bir vaka çalışmasının çözülmesine dayanmaktadır.
#
# “Bay Aman kendi cep telefonu şirketini kurmak istiyor ve Samsung ve Apple gibi büyük akıllı telefon markalarıyla zorlu bir mücadele yürütmek istiyor. Ancak hem pazarlama hem de üretim maliyetlerini karşılayabilecek bir cep telefonunun fiyatını nasıl tahmin edeceğini bilmiyor. Yani bu görevde cep telefonlarının gerçek fiyatlarını tahmin etmenize gerek yok ancak cep telefonlarının fiyat aralığını tahmin etmeniz gerekiyor. ”
#
# Python kullanarak Mobil Fiyat Sınıflandırması
# Dolayısıyla, görevimiz cep telefonlarının fiyat aralığını sınıflandırmak ve gerçek fiyatları tahmin etmek olmadığından, burada cep telefonlarının fiyat aralığını şu şekilde sınıflandırmak için bir sınıflandırma modeli eğiteceğim:
#
# 0 (düşük maliyet)
# 1 (orta maliyet)
# 2 (yüksek maliyet)
# 4 (çok yüksek maliyet)
# Mobil fiyat sınıflandırması görevine gerekli Python kütüphanelerini ve veri setini içe aktararak makine öğrenimi ile başlayacağım:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
sns.set()

# %%
df = pd.read_csv("mobile_prices.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", linecolor='white', linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preparation

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
x = StandardScaler().fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %% [markdown]
# ## Mobile Price Classification Model

# %%
from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression()
lreg.fit(x_train, y_train)
y_pred = lreg.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred) * 100
print("Accuracy of the Logistic Regression Model: ",accuracy)
# Out:
# Accuracy of the Logistic Regression Model:  95.5

# %%
y_pred
# Out:
# array([3, 0, 2, 2, 3, 0, 0, 3, 3, 1, 1, 3, 0, 2, 3, 0, 3, 2, 2, 1, 0, 0,
#        3, 1, 2, 2, 3, 1, 3, 1, 1, 0, 2, 0, 2, 3, 0, 0, 3, 3, 3, 1, 3, 3,
#        1, 3, 0, 1, 3, 1, 1, 3, 0, 3, 0, 2, 2, 2, 0, 3, 3, 1, 3, 2, 1, 2,
#        3, 2, 2, 2, 3, 2, 1, 0, 1, 3, 2, 2, 1, 2, 3, 3, 3, 0, 0, 0, 2, 1,
#        2, 3, 1, 2, 2, 1, 0, 3, 3, 3, 0, 3, 1, 1, 3, 1, 3, 2, 2, 3, 2, 3,
#        3, 0, 0, 1, 3, 3, 0, 0, 1, 0, 0, 3, 2, 2, 1, 2, 1, 1, 0, 2, 1, 3,
#        3, 3, 3, 3, 3, 2, 0, 1, 1, 2, 1, 3, 0, 3, 0, 0, 2, 0, 1, 1, 1, 1,
#        3, 0, 0, 3, 1, 3, 2, 1, 3, 1, 2, 3, 3, 2, 1, 0, 3, 1, 2, 3, 3, 0,
#        2, 2, 3, 1, 2, 1, 0, 1, 2, 2, 2, 0, 3, 3, 1, 1, 0, 2, 3, 0, 1, 2,
#        2, 0, 3, 3, 3, 1, 2, 3, 3, 3, 0, 0, 0, 2, 3, 3, 0, 0, 1, 3, 2, 3,
#        3, 3, 0, 0, 2, 3, 3, 1, 0, 2, 0, 0, 0, 3, 2, 1, 2, 2, 1, 1, 0, 2,
#        3, 3, 0, 0, 1, 3, 3, 1, 3, 0, 3, 1, 1, 0, 2, 3, 3, 2, 0, 0, 1, 2,
#        3, 2, 2, 3, 2, 1, 0, 3, 3, 2, 1, 3, 2, 2, 2, 1, 0, 2, 2, 1, 0, 0,
# ...

# %% [raw]
# Yukarıdaki çıktı modele göre sınıflandırılan fiyat aralığını gösterir. Her fiyat aralığı için sınıflandırılan cep telefonu sayısına bir göz atalım:

# %%
(unique, counts) = np.unique(y_pred, return_counts=True)
price_range = np.asarray((unique, counts)).T
print(price_range)
# Out:
# [[  0  95]
#  [  1  90]
#  [  2  97]
#  [  3 118]]
