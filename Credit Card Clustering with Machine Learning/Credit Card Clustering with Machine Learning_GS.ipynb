# %% [markdown]
# # Credit Card Clustering with Machine Learning

# %% [markdown]
# <img src='kredikartlari.jpg' width=1000>

# %% [raw]
# Kredi kartı kümelemesi, kredi kartı sahiplerini satın alma alışkanlıklarına, kredi limitlerine ve diğer birçok finansal faktöre göre gruplandırma görevidir.
# Kredi kartı segmentasyonu olarak da bilinir. Bu tür kümelenme analizi, işletmelerin potansiyel müşterilerini ve daha birçok pazarlama stratejisini bulmalarına yardımcı olur.

# %%
import pandas as pd
import numpy as np
from sklearn import cluster
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df=pd.read_csv("CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [raw]
# CUST_ID: Müşterinin benzersiz kimlik numarası
# BALANCE: Müşterinin banka hesabındaki bakiye
# BALANCE_FREQUENCY: Bakiyenin müşterinin hesabında ne sıklıkta güncellendiği (1 sık sık güncellenen, 0 ise sık sık güncellenmeyen anlamına gelir)
# PURCHASES: Müşterinin yaptığı satın alma sayısı
# ONEOFF_PURCHASES: Maksimum tek seferlik satın alma miktarı
# INSTALLMENTS_PURCHASES: Taksitli satın alma tutarı
# CASH_ADVANCE: Müşteri tarafından ödenen peşin nakit
# PURCHASES_FREQUENCY: Satın alma sıklığı (1 yüksek frekans, 0 düşük frekans anlamına gelir)
# ONEOFF_PURCHASES_FREQUENCY: Tek seferlik ödeme alımlarının sıklığı (1 yüksek frekans, 0 düşük frekans anlamına gelir)
# PURCHASES_INSTALLMENTS_FREQUENCY: Taksitli alımların sıklığı (1 yüksek frekans, 0 düşük frekans anlamına gelir)
# CASH_ADVANCE_FREQUENCY: Peşin ödemelerde nakit sıklığı
# CASH_ADVANCE_TRX: Peşin işlemlerde nakit sayısı
# PURCHASES_TRX: Satın alımlarda işlem sayısı
# CREDIT_LIMIT: Müşterinin kredi limiti
# PAYMENTS: Müşteri tarafından yapılan ödemelerin tutarı
# MINIMUM_PAYMENTS: Müşteri tarafından yapılan minimum ödemelerin tutarı
# PRC_FULL_PAYMENT: Müşteri tarafından yapılan tam ödemenin yüzdesi
# TENURE: Müşterinin kredi kartı hizmetinin kullanım süresi

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df=df.dropna()
#MINIMUM_PAYMENTS sütununda bulunan bos verilerden dolayi bu sütunu siliyorum.

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [raw]
# Veri setinde kredi kartı segmentasyonu görevi için çok değerli olan üç özellik bulunmaktadır:
#
# BAKİYE: Kredi kartı müşterilerinin hesaplarında kalan bakiye.
# SATIN ALMALAR: Kredi kartı müşterilerinin hesaplarından yapılan satın alma tutarı.
# CREDIT_LIMIT: Kredi kartının limiti.
#
# Bu üç özellik, kredi kartı sahiplerinin satın alma geçmişini, banka bakiyesini ve kredi limitini bize anlatırken kredi kartı sahiplerini gruplandırmak için yeterlidir. O halde veri kümesinden kümeler oluşturmak için bu özellikleri kullanalım:

# %%
x = df[["BALANCE", "PURCHASES", "CREDIT_LIMIT"]]
from sklearn.preprocessing import MinMaxScaler
for i in x.columns:
    MinMaxScaler()

from sklearn.cluster import KMeans
km=KMeans(n_clusters=5)
cluster=km.fit_predict(x)
df["CREDIT_CARD_SEGMENTS"]=cluster # CREDIT_CARD_SEGMENTS yeni bir sütun ekledim

# %%
df["CREDIT_CARD_SEGMENTS"] = df["CREDIT_CARD_SEGMENTS"].map({0: "Cluster 1", 1: 
    "Cluster 2", 2: "Cluster 3", 3: "Cluster 4", 4: "Cluster 5"})

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df["CREDIT_CARD_SEGMENTS"].head(10)
# Out:
# 0     Cluster 2
# 1     Cluster 5
# 2     Cluster 5
# 4     Cluster 2
# 5     Cluster 2
# 6     Cluster 3
# 7     Cluster 2
# 8     Cluster 5
# 9     Cluster 3
# 10    Cluster 2
# Name: CREDIT_CARD_SEGMENTS, dtype: object

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
silhouette_score(x,cluster)
# Out:
# np.float64(0.45571633820371804)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x.BALANCE, x.PURCHASES, c=cluster)
plt.xlabel("CREDIT_CARD_SEGMENTS")
plt.ylabel('CREDIT_LIMIT')
# Out:
# Text(0, 0.5, 'CREDIT_LIMIT')

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
km=KMeans()
vis=KElbowVisualizer(km,k=(2,10))
vis.fit(x)
vis.show()
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [raw]
# yukaridaki grafikte datanin optimum kaca bölünecegini daha net bir sekilde gösteriyor. 4 deki cizgiyle bunu daha net bir sekilde görebiliyoruz.
# vis=KElbowVisualizer(km,k=(2,10)) burada datayi en az 2 kümeye bölmemiz gerektigi icin 2 ile 10 araliginda böl manasinda (2,10) degerini veriyoruz.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df=linkage(x,method='ward', metric='euclidean')

# %%
plt.figure(figsize=(25,6))
dendrogram(df);
plt.savefig('x.png') # asagidaki tabloyu calismis oldugumuz klasöre kayit eder.

# %% [raw]
# Özet
# Kredi kartı kümesi analizi, kredi kartı sahiplerini satın alma alışkanlıklarına, kredi limitlerine ve daha birçok finansal faktöre göre gruplandırmak anlamına gelir. Bu tür kümelenme analizi, işletmelerin potansiyel müşterilerini ve daha birçok pazarlama stratejisini bulmalarına yardımcı olur.
