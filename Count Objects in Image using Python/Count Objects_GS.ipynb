# %% [markdown]
# # Count Objects in Image using Python

# %% [raw]
# Proje Özeti: Python ile Görüntüdeki Nesneleri Sayma
# Bu proje, bilgisayarlı görme alanında önemli bir görevi, yani bir görüntüdeki nesneleri saymayı hedeflemektedir. Python programlama dili kullanarak, bu görev için çeşitli kütüphaneler mevcuttur. Özellikle, cvlib kütüphanesi, nesne algılama konusunda yüksek seviyeli ve kullanıcı dostu bir çözüm sunmaktadır.
#
# Proje kapsamında, bir görüntüdeki nesneleri saymak için önce OpenCV kütüphanesi ile görüntüyü okuyacağız. Ardından, cvlib kullanarak bu görüntüdeki nesneleri algılayacağız ve belirli nesnelerin sayısını hesaplayacağız. Örnek olarak, bir görüntüdeki araçları tespit edip, toplam kaç araç olduğunu saymayı amaçlıyoruz.
#
# Bu çalışma, bilgisayarlı görmenin pratik uygulamalarını anlamak ve nesne tanıma tekniklerini kullanarak veri analizi yapmak için bir fırsat sunmaktadır. Sonuç olarak, bu proje ile görsel verilerden anlamlı bilgiler elde etmeyi amaçlıyoruz.

# %% [markdown]
# <img src='cars.jpg'>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

# %%
image = cv2.imread("cars.jpg")
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)
plt.imshow(output)
plt.show()
print("Number of cars in this image are " +str(label.count('car')))
# Out:
# Number of cars in this image are 15

# %% [raw]
# Özet
# Python'daki cvlib kitaplığını kullanarak nesne sayısını bu şekilde sayabilirsiniz. Bu kütüphaneyi bilgisayarlı görmenin tüm görevleri için kullanabilirsiniz. Umarım Python kullanarak bir görüntüdeki bir nesnenin nasıl sayılacağına ilişkin bu makaleyi beğenmişsinizdir.
